# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing,HoltWintersResults
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %%
ts_df = pd.read_csv('../data/tsdata.csv')

# write a function to loop over each custnum and create a dataframe create a list of dataframes, 
#then loop over list of dfs and fit/predict model and append results into results df

# %%
ts_df.groupby(ts_df.custnum).count()
# Out:
#          saledate  Equipsales
# custnum
# 100803         61          61
# 101434         61          61
# 104573         61          61
# 105751         61          61
# 107963         61          61
# 108277         61          61
# 108503         61          61
# 109330         61          61
# 120253         61          61
# 120715         61          61
# 120725         61          61
# 121216         61          61
# 122501         61          61
# 122835         61          61
# 123529         61          61
# 123616         61          61
# 124886         61          61
# 124932         61          61
# 125859         61          61
# 126354         61          61
# 126638         61          61
# 127444         61          61
# 128074         61          61
# 128874         61          61
# 128887         61          61
# 129068         61          61
# 130130         61          61
# 130682         61          61
# 135485         61          61
# ...

# %%
# ts_df.groupby(ts_df.custnum).count()

ts_df.saledate = pd.to_datetime(ts_df.saledate)

custlist= [set(ts_df.custnum)]


ts_df_test2 = ts_df[ts_df.custnum==100803].sort_values(by='saledate').set_index('saledate',drop=True).drop(columns='custnum')

# %%
modeltest = ExponentialSmoothing(ts_df_test2.Equipsales,trend='add',seasonal='add',seasonal_periods=12)
# Out:
# c:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
fit2 = modeltest.fit(use_boxcox=True)

start = '2018-09-01'
end = '2019-04-01'

predicttest = fit2.predict(start=start,end=end)

predtest = pd.DataFrame(data=predicttest).rename(columns={0:'Equipsales'})

# %%
ts_df_test2
# Out:
#             Equipsales
# saledate
# 2014-01-01    49546.00
# 2014-02-01    26857.00
# 2014-03-01    54599.00
# 2014-04-01   185535.00
# 2014-05-01   234718.45
# 2014-06-01   258666.00
# 2014-07-01   154318.00
# 2014-08-01   114142.00
# 2014-09-01   148111.00
# 2014-10-01   111321.00
# 2014-11-01    83218.00
# 2014-12-01    27816.00
# 2015-01-01    99811.00
# 2015-02-01    81617.00
# 2015-03-01    65382.00
# 2015-04-01   399944.70
# 2015-05-01   169882.35
# 2015-06-01   386696.45
# 2015-07-01   362168.65
# 2015-08-01   214464.90
# 2015-09-01   148497.75
# 2015-10-01   125812.15
# 2015-11-01   124416.40
# 2015-12-01   141945.00
# 2016-01-01   171311.57
# 2016-02-01   356565.90
# 2016-03-01   128314.45
# 2016-04-01   121384.95
# 2016-05-01   247735.20
# 2016-06-01   275614.78
# ...                ...
# 2016-08-01   286866.78
# 2016-09-01   198789.75
# 2016-10-01   111312.30
# 2016-11-01    79158.46
# 2016-12-01   122115.19
# 2017-01-01    82573.60
# 2017-02-01    69364.16
# ...

# %%
predtest
# Out:
#                Equipsales
# 2018-09-01  323717.175917
# 2018-10-01  305335.106201
# 2018-11-01  319943.050181
# 2018-12-01  237268.382839
# 2019-01-01  329254.656889
# 2019-02-01  262007.946224
# 2019-03-01  412951.536229
# 2019-04-01  651401.637414

# %%
plt.figure(figsize=[12,8])
plt.plot(ts_df_test2[:-1])
plt.plot(predtest)

# %%
params = {
    'trend':'additive',
    'seasonal':'add',
    'seasonal_periods':12
}

modeltest.score(params)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-16-41ed7833ce4c> in <module>()
#       5 }
#       6
# ----> 7 modeltest.score(params)
#
# c:\Anaconda\lib\site-packages\statsmodels\base\model.py in score(self, params)
#     236         The gradient of logL with respect to each parameter.
#     237         """
# --> 238         raise NotImplementedError
#     239
#     240     def information(self, params):
#
# NotImplementedError:

# %%
resultsdf_list = []

start='2018-11-01'
end = '2019-09-01'

for id in custlist:
    ts_df_test = ts_df[ts_df.custnum == id].sort_values(by='saledate').set_index('saledate',drop=True).drop(columns='custnum')
    ts_df_test = ts_df_test.asfreq('MS')
    print(ts_df_test)
    model = ExponentialSmoothing(ts_df_test.Equipsales,trend='additive',seasonal='add',seasonal_periods=12)
    
    fit = model.fit(use_boxcox=True)

    predict = fit.predict(start=start,end=end)

    id = pd.DataFrame(data=predict).rename(columns={0:'Equipsales'})
    
#     print(f'Adding predicted results for: {id[0]}')
    
    resultsdf_list.append(id)
# Out:
# Empty DataFrame
# Columns: [Equipsales]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-8fc088608e2b> in <module>()
#      11     model = ExponentialSmoothing(ts_df_test.Equipsales,trend='additive',seasonal='add',seasonal_periods=12)
#      12
# ---> 13     fit = model.fit(use_boxcox=True)
#      14
#      15     predict = fit.predict(start=start,end=end)
#
# c:\Anaconda\lib\site-packages\statsmodels\tsa\holtwinters.py in fit(self, smoothing_level, smoothing_slope, smoothing_seasonal, damping_slope, optimized, use_boxcox, remove_bias, use_basinhopping)
#     507             y = boxcox(data, lamda)
#     508         elif use_boxcox:
# --> 509             y, lamda = boxcox(data)
#     510         else:
#     511             lamda = None
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
results_with_custnm = []
for i,j in custlist.index,results_df.index:
    results_with_custnm.append(results_df[['custnum'][j] == custlist[i]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c6fed3ab0821> in <module>()
#       1 results_with_custnm = []
# ----> 2 for i,j in custlist.index,results_df.index:
#       3     results_with_custnm.append(results_df[['custnum'][j] == custlist[i]])
#
# NameError: name 'results_df' is not defined
