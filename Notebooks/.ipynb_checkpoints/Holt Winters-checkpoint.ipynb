# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing,HoltWintersResults
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %%
ts_df = pd.read_csv('../data/tsdata.csv')

# write a function to loop over each custnum and create a dataframe create a list of dataframes, 
#then loop over list of dfs and fit/predict model and append results into results df

# %%
ts_df.groupby(ts_df.custnum).count()

# %%
# ts_df.groupby(ts_df.custnum).count()

# ts_df.saledate = pd.to_datetime(ts_df.saledate,yearfirst=True)

# custlist= set(ts_df.custnum)


ts_df_test2 = ts_df[ts_df.custnum==124932].sort_values(by='saledate').set_index('saledate',drop=True).drop(columns='custnum')

# %%
modeltest = ExponentialSmoothing(ts_df_test2.Equipsales,trend='add',seasonal='add',seasonal_periods=12)
# Out:
# c:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
fit2 = modeltest.fit(use_boxcox=True)

start='2018-09-01'
end = '2019-04-01'

predicttest = fit2.predict(start=start,end=end)

predtest = pd.DataFrame(data=predicttest).rename(columns={0:'Equipsales'})

# %%
ts_df_test2
# Out:
#             Equipsales
# saledate
# 2014-01-01        1.00
# 2014-02-01      997.00
# 2014-03-01      312.00
# 2014-04-01        1.00
# 2014-05-01     1753.00
# 2014-06-01     6727.00
# 2014-07-01      411.00
# 2014-08-01     1934.00
# 2014-09-01     4829.00
# 2014-10-01    97434.00
# 2014-11-01    87583.30
# 2014-12-01    84513.00
# 2015-01-01     8676.00
# 2015-02-01     9588.42
# 2015-03-01    92811.27
# 2015-04-01    19288.00
# 2015-05-01    15517.21
# 2015-06-01    42378.59
# 2015-07-01    57512.00
# 2015-08-01     7511.00
# 2015-09-01    26372.00
# 2015-10-01    28138.80
# 2015-11-01    15261.00
# 2015-12-01   176254.33
# 2016-01-01    12663.00
# 2016-02-01    36932.00
# 2016-03-01    48166.00
# 2016-04-01    88722.00
# 2016-05-01    71151.43
# 2016-06-01    66668.30
# ...                ...
# 2016-08-01    17988.00
# 2016-09-01    27661.00
# 2016-10-01    43157.30
# 2016-11-01    46546.00
# 2016-12-01   155881.00
# 2017-01-01    27712.32
# 2017-02-01    15889.00
# 2017-03-01    32455.00
# 2017-04-01    21883.00
# 2017-05-01    63849.00
# 2017-06-01   114319.00
# 2017-07-01    24114.00
# 2017-08-01    38118.00
# 2017-09-01    25391.00
# 2017-10-01    77817.00
# 2017-11-01    16468.00
# 2017-12-01     3998.00
# 2018-01-01    82316.50
# 2018-02-01   115911.53
# 2018-03-01   111899.00
# 2018-04-01    44654.40
# 2018-05-01    38473.13
# 2018-06-01    59442.00
# 2018-07-01    92297.00
# 2018-08-01    43313.00
# 2018-09-01    51316.00
# 2018-10-01    71324.00
# 2018-11-01    52422.00
# 2018-12-01   117849.00
# 2019-01-01    38124.00
#
# [61 rows x 1 columns]

# %%
predtest
# Out:
#                Equipsales
# 2018-09-01   51945.414943
# 2018-10-01  105559.643895
# 2018-11-01   66961.211514
# 2018-12-01  125663.363656
# 2019-01-01   46900.923583
# 2019-02-01   60627.784590
# 2019-03-01   92018.520523
# 2019-04-01   59940.794693

# %%
plt.figure(figsize=[12,8])
plt.plot(ts_df_test2[:-1])
plt.plot(predtest)

# %%
params = {
    'trend':'additive',
    'seasonal':'add',
    'seasonal_periods':12
}

HoltWintersResults(model,params,'aic')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-456a1b9c160b> in <module>()
#       5 }
#       6
# ----> 7 HoltWintersResults(model,params,'aic')
#
# TypeError: __init__() takes 3 positional arguments but 4 were given

# %%
resultsdf_list = []

start='2018-11-01'
end = '2019-09-01'

for id in custlist:
    ts_df_test = ts_df[ts_df.custnum == id].sort_values(by='saledate').set_index('saledate',drop=True).drop(columns='custnum')
 
    model = ExponentialSmoothing(ts_df_test.Equipsales,trend='additive',seasonal='add',seasonal_periods=12)
    
    fit = model.fit(use_boxcox=True)

    predict = fit.predict(start=start,end=end)

    id = pd.DataFrame(data=predict).rename(columns={0:'Equipsales'})
    
#     print(f'Adding predicted results for: {id[0]}')
    
    resultsdf_list.append(id)

# %%
merged = list(zip(resultsdf_list,custlist))
merged[0]
# Out:
# (               Equipsales
#  2018-11-01   66961.211514
#  2018-12-01  125663.363656
#  2019-01-01   46900.923583
#  2019-02-01   60627.784590
#  2019-03-01   92018.520523
#  2019-04-01   59940.794693
#  2019-05-01   72631.012564
#  2019-06-01  105671.763890
#  2019-07-01   78410.015953
#  2019-08-01   50202.952088
#  2019-09-01   63481.083398, 124932)
